# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# Create an empty DataFrame with columns
data = {
    'Link': [],
    'Job title': [],
    'Company name': [],
    'Location': [],
    'Salary':[],
    'Description': [],
    'Seniority level': [],
    'Employment type': [],
    'Job function': [],
    'Industries': []
}

# %%
#url = "https://www.linkedin.com/jobs/data-scientist-jobs?position=1&pageNum=0"
url = 'https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/data-scientist-jobs?position=1&pageNum=1&start=200'

# %%
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
ul = soup.find('ul', class_ = 'jobs-search__results-list')

# %%
for num in range(3):
    response = requests.get(f'https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/data-scientist-jobs?position={num+1}&pageNum=0&start=50')
    soup = BeautifulSoup(response.text, 'html.parser')
    for li in soup.find_all('li'):
        try:
            print(f"Salary info: {li.find('span', class_='job-search-card__salary-info').text}")
            salary = li.find('span', class_='job-search-card__salary-info').text
        except:
            continue
        link = li.find('div').find('a').get('href')
        print(link)
        soup2 = BeautifulSoup(requests.get(link).text, 'html.parser')
        crits = {}
        try:
            for li in soup2.find('ul', class_='description__job-criteria-list').find_all('li'):
                crits[li.find('h3').text.strip()] = li.find('span').text.strip()
        except:
            continue
        print(crits.keys())
        data['Link'].append(link)
        try:
            data['Salary'].append(salary)
        except:
            data['Salary'].append(None)

        data['Job title'].append(soup2.find('h1', class_='topcard__title').text.strip())
        data['Company name'].append(soup2.find('a', class_='topcard__org-name-link topcard__flavor--black-link').text.strip())
        data['Location'].append(soup2.find('span', class_='topcard__flavor topcard__flavor--bullet').text.strip())
        data['Description'].append(soup2.find('div', class_='show-more-less-html__markup').text.strip())
        data['Seniority level'].append(crits['Seniority level'] if 'Seniority level' in crits.keys() else None)
        data['Employment type'].append(crits['Employment type'] if 'Employment type' in crits.keys() else None)
        data['Job function'].append(crits['Job function'] if 'Job function' in crits.keys() else None)
        data['Industries'].append(crits['Industries'] if 'Industries' in crits.keys() else None)
# Out:
# Salary info:
#             $118,400.00
#             -
#             $222,000.00
#
# https://www.linkedin.com/jobs/view/senior-data-scientist-at-sofi-3757406771?refId=%2BU6Jqe4frY0Iep4IeznJBA%3D%3D&trackingId=QQal9LWLluG2VeQz1giWBQ%3D%3D&position=7&pageNum=2&trk=public_jobs_jserp-result_search-card
# dict_keys(['Seniority level', 'Employment type', 'Job function', 'Industries'])
# Salary info:
#             $118,400.00
#             -
#             $222,000.00
#
# https://www.linkedin.com/jobs/view/senior-data-scientist-at-sofi-3757406772?refId=%2BU6Jqe4frY0Iep4IeznJBA%3D%3D&trackingId=oMviKFsKWwt7bZc4FVxmXw%3D%3D&position=11&pageNum=2&trk=public_jobs_jserp-result_search-card
# dict_keys(['Seniority level', 'Employment type', 'Job function', 'Industries'])
# Salary info:
#             $118,400.00
#             -
#             $222,000.00
#
# https://www.linkedin.com/jobs/view/senior-data-scientist-at-sofi-3757404895?refId=%2BU6Jqe4frY0Iep4IeznJBA%3D%3D&trackingId=y9dnCoyaLvZTADdFK%2F0GzQ%3D%3D&position=18&pageNum=2&trk=public_jobs_jserp-result_search-card
# dict_keys(['Seniority level', 'Employment type', 'Job function', 'Industries'])
# Salary info:
#             $118,400.00
#             -
#             $222,000.00
#
# https://www.linkedin.com/jobs/view/senior-data-scientist-at-sofi-3757408625?refId=%2BU6Jqe4frY0Iep4IeznJBA%3D%3D&trackingId=usG23L5YUmaHzBVS9D8oNA%3D%3D&position=19&pageNum=2&trk=public_jobs_jserp-result_search-card
# dict_keys(['Seniority level', 'Employment type', 'Job function', 'Industries'])
# Salary info:
#             $118,400.00
#             -
#             $222,000.00
#
# https://www.linkedin.com/jobs/view/senior-data-scientist-at-sofi-3757406771?refId=QJFrkh%2BPC1QkxnV4beBm0Q%3D%3D&trackingId=jQ%2FW2x9NxTShU5tAQwp83Q%3D%3D&position=7&pageNum=2&trk=public_jobs_jserp-result_search-card
# dict_keys(['Seniority level', 'Employment type', 'Job function', 'Industries'])
# 11  https://www.linkedin.com/jobs/view/senior-data...  Senior Data Scientist
# 12  https://www.linkedin.com/jobs/view/senior-data...  Senior Data Scientist
#
#    Company name                Location  \
# 0          SoFi              Frisco, TX
# 1          SoFi           Charlotte, NC
# 2          SoFi  Cottonwood Heights, UT
# 3          SoFi  Cottonwood Heights, UT
# 4          SoFi              Frisco, TX
# 5          SoFi           Charlotte, NC
# 6          SoFi  Cottonwood Heights, UT
# 7          SoFi  Cottonwood Heights, UT
# 8          SoFi        Jacksonville, FL
# 9          SoFi              Frisco, TX
# 10         SoFi           Charlotte, NC
# 11         SoFi  Cottonwood Heights, UT
# 12         SoFi  Cottonwood Heights, UT
#
#                                                Salary  \
# 0   \n            $118,400.00\n            -\n    ...
# 1   \n            $118,400.00\n            -\n    ...
# 2   \n            $118,400.00\n            -\n    ...
# 3   \n            $118,400.00\n            -\n    ...
# 4   \n            $118,400.00\n            -\n    ...
# 5   \n            $118,400.00\n            -\n    ...
# 6   \n            $118,400.00\n            -\n    ...
# 7   \n            $118,400.00\n            -\n    ...
# 8   \n            $118,400.00\n            -\n    ...
# 9   \n            $118,400.00\n            -\n    ...
# 10  \n            $118,400.00\n            -\n    ...
# 11  \n            $118,400.00\n            -\n    ...
# 12  \n            $118,400.00\n            -\n    ...
#
#                                           Description Seniority level  \
# 0   Employee Applicant Privacy NoticeWho we are:Sh...  Not Applicable
# 1   Employee Applicant Privacy NoticeWho we are:Sh...  Not Applicable
# 2   Employee Applicant Privacy NoticeWho we are:Sh...  Not Applicable
# 3   Employee Applicant Privacy NoticeWho we are:Sh...  Not Applicable
# 4   Employee Applicant Privacy NoticeWho we are:Sh...  Not Applicable
# 5   Employee Applicant Privacy NoticeWho we are:Sh...  Not Applicable
# 6   Employee Applicant Privacy NoticeWho we are:Sh...  Not Applicable
# 7   Employee Applicant Privacy NoticeWho we are:Sh...  Not Applicable
# 8   Employee Applicant Privacy NoticeWho we are:Sh...  Not Applicable
# 9   Employee Applicant Privacy NoticeWho we are:Sh...  Not Applicable
# 10  Employee Applicant Privacy NoticeWho we are:Sh...  Not Applicable
# 11  Employee Applicant Privacy NoticeWho we are:Sh...  Not Applicable
# 12  Employee Applicant Privacy NoticeWho we are:Sh...  Not Applicable
#
#    Employment type                            Job function          Industries
# 0        Full-time  Engineering and Information Technology  Financial Services
# 1        Full-time  Engineering and Information Technology  Financial Services
# 2        Full-time  Engineering and Information Technology  Financial Services
# 3        Full-time  Engineering and Information Technology  Financial Services
# 4        Full-time  Engineering and Information Technology  Financial Services
# 5        Full-time  Engineering and Information Technology  Financial Services
# 6        Full-time  Engineering and Information Technology  Financial Services
# 7        Full-time  Engineering and Information Technology  Financial Services
# 8        Full-time  Engineering and Information Technology  Financial Services
# 9        Full-time  Engineering and Information Technology  Financial Services
# 10       Full-time  Engineering and Information Technology  Financial Services
# 11       Full-time  Engineering and Information Technology  Financial Services
# 12       Full-time  Engineering and Information Technology  Financial Services

# %%
df.iloc[21]['Link']
# Out:
# 'https://www.linkedin.com/jobs/view/product-data-scientists-at-upwork-3747085114?refId=f%2FUhYHAJh%2Bcg30G3TQ7zFw%3D%3D&trackingId=jUCtZREiq9SzBTJcqx3pXA%3D%3D&position=24&pageNum=0&trk=public_jobs_jserp-result_search-card'

# %%
df.to_csv('data2.csv', index=False)
