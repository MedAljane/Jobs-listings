# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# Create an empty DataFrame with columns
data = {
    'Link': [],
    'Job title': [],
    'Company name': [],
    'Location': [],
    'Salary':[],
    'Description': [],
    'Seniority level': [],
    'Employment type': [],
    'Job function': [],
    'Industries': []
}

# %%
for num in range(25, 501, 25):
    print(f"request for {num}")
    response = requests.get(f'https://www.linkedin.com/jobs-guest/jobs/api/seeMoreJobPostings/data-scientist-jobs?position=1&pageNum=0&start={num}')
    soup = BeautifulSoup(response.text, 'html.parser')
    length_results = len(soup.find_all('li'))
    for number, li in enumerate(soup.find_all('li')):
        print(f"result {number}/{length_results}")
        try:
            salary = li.find('span', class_='job-search-card__salary-info').text.strip()
        except:
            salary = 'not found'

        link = li.find('a', class_='base-card__full-link').get('href')
        print(link)

        soup2 = BeautifulSoup(requests.get(link).text, 'html.parser')
        crits = {}
        try:
            for li in soup2.find('ul', class_='description__job-criteria-list').find_all('li'):
                crits[li.find('h3').text.strip()] = li.find('span').text.strip()
        except:
            pass
        print(crits.keys())

        data['Link'].append(link)
        try:
            data['Salary'].append(salary)
        except:
            data['Salary'].append(None)

        try:
            data['Job title'].append(soup2.find('h1', class_='topcard__title').text.strip())
        except:
            data['Job title'].append('not Found')

        try:
            data['Company name'].append(soup2.find('a', class_='topcard__org-name-link topcard__flavor--black-link').text.strip())
        except:
            data['Company name'].append('not Found')

        try:
            data['Location'].append(soup2.find('span', class_='topcard__flavor topcard__flavor--bullet').text.strip())
        except:
            data['Location'].append('not Found')
            
        try:
            data['Description'].append(soup2.find('div', class_='show-more-less-html__markup').text.strip())
        except:
            data['Description'].append('not Found')
            

        data['Seniority level'].append(crits['Seniority level'] if 'Seniority level' in crits.keys() else None)
        data['Employment type'].append(crits['Employment type'] if 'Employment type' in crits.keys() else None)
        data['Job function'].append(crits['Job function'] if 'Job function' in crits.keys() else None)
        data['Industries'].append(crits['Industries'] if 'Industries' in crits.keys() else None)
# Out:
# request for 25
# result 0/25
# https://www.linkedin.com/jobs/view/data-scientist-at-stemboard-3746740797?refId=sVNWh%2Bq0%2BkkeK6rlcmxRCg%3D%3D&trackingId=hZnlo7j8wEW8JJFQccfy1g%3D%3D&position=1&pageNum=1&trk=public_jobs_jserp-result_search-card
# dict_keys(['Seniority level', 'Employment type', 'Job function', 'Industries'])
# result 1/25
# https://www.linkedin.com/jobs/view/data-scientist-marketing-analytics-at-marketbridge-3752271170?refId=sVNWh%2Bq0%2BkkeK6rlcmxRCg%3D%3D&trackingId=k96tZNkQksVBVKs13ZGsGA%3D%3D&position=2&pageNum=1&trk=public_jobs_jserp-result_search-card
# dict_keys(['Seniority level', 'Employment type', 'Job function', 'Industries'])
# result 2/25
# https://www.linkedin.com/jobs/view/data-scientist-%24175k%2B-at-henderson-harbor-group-3757450438?refId=sVNWh%2Bq0%2BkkeK6rlcmxRCg%3D%3D&trackingId=kdmytvocn1op6HfoLDfmyA%3D%3D&position=3&pageNum=1&trk=public_jobs_jserp-result_search-card
# dict_keys(['Seniority level', 'Employment type', 'Job function', 'Industries'])
# result 3/25
# https://www.linkedin.com/jobs/view/deep-learning-engineer-at-cyberjin-3757438652?refId=sVNWh%2Bq0%2BkkeK6rlcmxRCg%3D%3D&trackingId=29Gjbgc7MxYJVFrXF6mplw%3D%3D&position=4&pageNum=1&trk=public_jobs_jserp-result_search-card
# dict_keys(['Seniority level', 'Employment type', 'Job function', 'Industries'])
# result
trk=public_jobs_jserp-result_search-card
# dict_keys(['Seniority level', 'Employment type', 'Job function', 'Industries'])
# result 2/25
# https://www.linkedin.com/jobs/view/machine-learning-engineer-at-marathon-ts-3753630905?refId=Ymq6crZwo3V4tyMGbh%2FBYg%3D%3D&trackingId=w1dehUJ3%2Bd35pPZRPki6kg%3D%3D&position=3&pageNum=2&trk=public_jobs_jserp-result_search-card
# dict_keys(['Seniority level', 'Employment type', 'Job function', 'Industries'])
# result 3/25
# https://www.linkedin.com/jobs/view/data-scientist-at-mayvue-solutions-3734612661?refId=Ymq6crZwo3V4tyMGbh%2FBYg%3D%3D&trackingId=5ooIEDM8%2B1%2FsjnuNJBk1WQ%3D%3D&position=4&pageNum=2&trk=public_jobs_jserp-result_search-card
# dict_keys(['Seniority level', 'Employment type', 'Job function', 'Industries'])
# result 4/25
# https://www.linkedin.com/jobs/view/deep-learning-engineer-at-cyberjin-3757439590?refId=Ymq6crZwo3V4tyMGbh%2FBYg%3D%3D&trackingId=gT0Yn%2FX6dfR7r%2FGXprMVDg%3D%3D&position=5&pageNum=2&trk=public_jobs_jserp-result_search-card
# dict_keys(['Seniority level', 'Employment type', 'Job function', 'Industries'])
# result 5/25
# https://www.linkedin.com/jobs/view/data-scientist-at-saransh-inc-3751103542?refId=Ymq6crZwo3V4tyMGbh%2FBYg%3D%3D&trackingId=Z9WmzaRHWqUC%2B7DRe3t1Vg%3D%3D&position=6&pageNum=2&trk=public_jobs_jserp-result_search-card
# dict_keys(['Seniority level', 'Employment type', 'Job function', 'Industries'])
# result 6/25
# https://www.linkedin.com/jobs/view/senior-data-scientist-at-sofi-3757406772?refId=Ymq6crZwo3V4tyMGbh%2FBYg%3D%3D&trackingId=FFgpIqmBF%2By%2BRsdrr8kFsQ%3D%3D&position=7&pageNum=2&trk=public_jobs_jserp-result_search-card
# dict_keys(['Seniority level', 'Employment type', 'Job function', 'Industries'])
# result 7/25
# https://www.linkedin.com/jobs/view/data-scientist-at-attain-3745196602?refId=Ymq6crZwo3V4tyMGbh%2FBYg%3D%3D&trackingId=pkzcD%2B6G8I8ByKRUkQJgKQ%3D%3D&position=8&pageNum=2&trk=public_jobs_jserp-result_search-card
# dict_keys(['Seniority level', 'Employment type', 'Job function', 'Industries'])
# result 8/25
# https://www.linkedin.com/jobs/view/deep-learning-engineer-at-cyberjin-3757435744?refId=Ymq6crZwo3V4tyMGbh%2FBYg%3D%3D&trackingId=4XjlP4H%2BW%2Fpbp161tR3vNw%3D%3D&position=9&pageNum=2&trk=public_jobs_jserp-result_search-card
# dict_keys(['Seniority level', 'Employment type', 'Job function', 'Industries'])
# result 9/25
# https://www.linkedin.com/jobs/view/data-scientist-entry-level-at-hiremefast-llc-secure-your-next-job-career-accelerator-3757196876?refId=Ymq6crZwo3V4tyMGbh%2FBYg%3D%3D&trackingId=2DHotzoyTN8snnvLXpBXdA%3D%3D&position=10&pageNum=2&trk=public_jobs_jserp-result_search-card
# dict_keys(['Seniority level', 'Employment type', 'Job function', 'Industries'])
# result 10/25
# https://www.linkedin.com/jobs/view/data-scientist-at-nucleix-ltd-3744925442?refId=Ymq6crZwo3V4tyMGbh%2FBYg%3D%3D&trackingId=exsXbbsSDi0054Bi%2F2qycA%3D%3D&position=11&pageNum=2&trk=public_jobs_jserp-result_search-card
# dict_keys(['Employment type'])
# result 11/25
# https://www.linkedin.com/jobs/view/machine-learning-software-engineer-at-syndio-3750687886?refId=Ymq6crZwo3V4tyMGbh%2FBYg%3D%3D&trackingId=k8eXN%2BYkj2SvVUUAzYKIQQ%3D%3D&position=12&pageNum=2&trk=public_jobs_jserp-result_search-card
# dict_keys([])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 30
#      27 except:
#      28     data['Salary'].append(None)
# ---> 30 data['Job title'].append(soup2.find('h1', class_='topcard__title').text.strip())
#      31 data['Company name'].append(soup2.find('a', class_='topcard__org-name-link topcard__flavor--black-link').text.strip())
#      32 data['Location'].append(soup2.find('span', class_='topcard__flavor topcard__flavor--bullet').text.strip())
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                                  Link  \
# 0   https://www.linkedin.com/jobs/view/senior-data...
# 1   https://www.linkedin.com/jobs/view/data-scient...
# 2   https://www.linkedin.com/jobs/view/data-scient...
# 3   https://www.linkedin.com/jobs/view/senior-data...
# 4   https://www.linkedin.com/jobs/view/data-scient...
# 5   https://www.linkedin.com/jobs/view/data-scient...
# 6   https://www.linkedin.com/jobs/view/senior-data...
# 7   https://www.linkedin.com/jobs/view/senior-data...
# 8   https://www.linkedin.com/jobs/view/senior-data...
# 9   https://www.linkedin.com/jobs/view/senior-data...
# 10  https://www.linkedin.com/jobs/view/senior-data...
# 11  https://www.linkedin.com/jobs/view/senior-data...
# 12  https://www.linkedin.com/jobs/view/senior-data...
# 13  https://www.linkedin.com/jobs/view/senior-data...
# 14  https://www.linkedin.com/jobs/view/data-scient...
# 15  https://www.linkedin.com/jobs/view/entry-level...
# 16  https://www.linkedin.com/jobs/view/senior-data...
# 17  https://www.linkedin.com/jobs/view/senior-data...
# 18  https://www.linkedin.com/jobs/view/data-scient...
#
#                                             Job title  \
# 0                               Senior Data Scientist
# 1                                      Data Scientist
# 2                                      Data Scientist
# 3                               Senior Data Scientist
# 4                                      Data Scientist
# 5                                      Data Scientist
# 6                               Senior Data Scientist
# 7                               Senior Data Scientist
# 8                               Senior Data Scientist
# 9                               Senior Data Scientist
# 10                              Senior Data Scientist
# 11                              Senior Data Scientist
# 12                              Senior Data Scientist
# 13                              Senior Data Scientist
# 14                                     Data Scientist
# 15  Entry Level - Associate Data Scientist - Comme...
# 16                              Senior Data Scientist
# 17                              Senior Data Scientist
# 18                                     Data Scientist
#
#                Company name                Location  \
# 0                      SoFi       San Francisco, CA
# 1                CVS Health            New York, NY
# 2          Aditi Consulting       Thousand Oaks, CA
# 3                      SoFi  Cottonwood Heights, UT
# 4                CVS Health            New York, NY
# 5                CVS Health            Hartford, CT
# 6                      SoFi            Claymont, DE
# 7                      SoFi            Claymont, DE
# 8                      SoFi        Jacksonville, FL
# 9                      SoFi        Jacksonville, FL
# 10                     SoFi           Charlotte, NC
# 11                     SoFi           Charlotte, NC
# 12                     SoFi              Frisco, TX
# 13            X4 Technology             Houston, TX
# 14  Primary Talent Partners       San Francisco, CA
# 15                      IBM            New York, NY
# 16                     SoFi  Cottonwood Heights, UT
# 17           Insight Global             Raleigh, NC
# 18  Primary Talent Partners       San Francisco, CA
#
#                                                Salary  \
# 0   \n            $118,400.00\n            -\n    ...
# 1   \n            $73,500.00\n            -\n     ...
# 2   \n            $48.20\n            -\n         ...
# 3   \n            $118,400.00\n            -\n    ...
# 4   \n            $80,500.00\n            -\n     ...
# 5   \n            $73,500.00\n            -\n     ...
# 6   \n            $118,400.00\n            -\n    ...
# 7   \n            $118,400.00\n            -\n    ...
# 8   \n            $118,400.00\n            -\n    ...
# 9   \n            $118,400.00\n            -\n    ...
# 10  \n            $118,400.00\n            -\n    ...
# 11  \n            $118,400.00\n            -\n    ...
# 12  \n            $118,400.00\n            -\n    ...
# 13  \n            $150,000.00\n            -\n    ...
# 14  \n            $95.00\n            -\n         ...
# 15  \n            $93,000.00\n            -\n     ...
# 16  \n            $118,400.00\n            -\n    ...
# 17  \n            $70.00\n            -\n         ...
# 18  \n            $95.00\n            -\n         ...
#
#                                           Description   Seniority level  \
# 0   Employee Applicant Privacy NoticeWho we are:Sh...    Not Applicable
# 1   Bring your heart to CVS Health. Every one of u...       Entry level
# 2   Job Title: Data ScientistLocation: Hybrid at T...  Mid-Senior level
# 3   Employee Applicant Privacy NoticeWho we are:Sh...    Not Applicable
# 4   Bring your heart to CVS Health. Every one of u...       Entry level
# 5   Bring your heart to CVS Health. Every one of u...       Entry level
# 6   Employee Applicant Privacy NoticeWho we are:Sh...    Not Applicable
# 7   Employee Applicant Privacy NoticeWho we are:Sh...    Not Applicable
# 8   Employee Applicant Privacy NoticeWho we are:Sh...    Not Applicable
# 9   Employee Applicant Privacy NoticeWho we are:Sh...    Not Applicable
# 10  Employee Applicant Privacy NoticeWho we are:Sh...    Not Applicable
# 11  Employee Applicant Privacy NoticeWho we are:Sh...    Not Applicable
# 12  Employee Applicant Privacy NoticeWho we are:Sh...    Not Applicable
# 13  Role & CompanyA Senior Data Scientist position...  Mid-Senior level
# 14  Primary Talent Partners has a 12 Month Contrac...       Entry level
# 15  657667BRIntroductionAs a Associate Data Scient...    Not Applicable
# 16  Employee Applicant Privacy NoticeWho we are:Sh...    Not Applicable
# 17  MUST be local to Raleigh, NCHybrid, 2 days in ...  Mid-Senior level
# 18  Primary Talent Partners has a 12 Month Contrac...       Entry level
#
#    Employment type                            Job function  \
# 0        Full-time  Engineering and Information Technology
# 1        Full-time  Engineering and Information Technology
# 2         Contract  Engineering and Information Technology
# 3        Full-time  Engineering and Information Technology
# 4        Full-time  Engineering and Information Technology
# 5        Full-time  Engineering and Information Technology
# 6        Full-time  Engineering and Information Technology
# 7        Full-time  Engineering and Information Technology
# 8        Full-time  Engineering and Information Technology
# 9        Full-time  Engineering and Information Technology
# 10       Full-time  Engineering and Information Technology
# 11       Full-time  Engineering and Information Technology
# 12       Full-time  Engineering and Information Technology
# 13       Full-time  Engineering and Information Technology
# 14        Contract                  Information Technology
# 15       Full-time                  Information Technology
# 16       Full-time  Engineering and Information Technology
# 17       Full-time  Engineering and Information Technology
# 18        Contract                  Information Technology
#
#                                            Industries
# 0                                  Financial Services
# 1                           Hospitals and Health Care
# 2                       IT Services and IT Consulting
# 3                                  Financial Services
# 4                           Hospitals and Health Care
# 5                           Hospitals and Health Care
# 6                                  Financial Services
# 7                                  Financial Services
# 8                                  Financial Services
# 9                                  Financial Services
# 10                                 Financial Services
# 11                                 Financial Services
# 12                                 Financial Services
# 13  Renewable Energy Semiconductor Manufacturing, ...
# 14                            Staffing and Recruiting
# 15                    Computer Hardware Manufacturing
# 16                                 Financial Services
# 17                      IT Services and IT Consulting
# 18                            Staffing and Recruiting

# %%
df.to_csv('data4.csv', index=False)
